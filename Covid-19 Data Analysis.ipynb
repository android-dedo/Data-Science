# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Egy-COVID-19.csv")

# %%
data
# Out:
#          date  new_confirmed  new_deaths  new_recovered  new_pos_to_neg  \
# 0    3/1/2020              1           0              0               0
# 1    3/2/2020              0           0              0               0
# 2    3/3/2020              0           0              0               0
# 3    3/4/2020              0           0              0               0
# 4    3/5/2020              1           0              0               0
# ..        ...            ...         ...            ...             ...
# 80  5/20/2020            745          21            252             309
# 81  5/21/2020            774          16            223             214
# 82  5/22/2020            783          11            157             162
# 83  5/23/2020            727          28            254             232
# 84  5/24/2020            752          29            179             174
#
#     active_pos  cases_in_hospital  total_confirmed  total_deaths  \
# ...

# %%
data.head()
# Out:
#        date  new_confirmed  new_deaths  new_recovered  new_pos_to_neg  \
# 0  3/1/2020              1           0              0               0
# 1  3/2/2020              0           0              0               0
# 2  3/3/2020              0           0              0               0
# 3  3/4/2020              0           0              0               0
# 4  3/5/2020              1           0              0               0
#
#    active_pos  cases_in_hospital  total_confirmed  total_deaths  \
# 0           1                  1                2             0
# 1           1                  1                2             0
# 2           1                  1                2             0
# 3           1                  1                2             0
# 4           2                  2                3             0
#
#    total_recovered  total_pos_to_neg lockdown  lockdown_duration
# 0                1                 1       No                  0
# ...

# %%
data.tail()
# Out:
#          date  new_confirmed  new_deaths  new_recovered  new_pos_to_neg  \
# 80  5/20/2020            745          21            252             309
# 81  5/21/2020            774          16            223             214
# 82  5/22/2020            783          11            157             162
# 83  5/23/2020            727          28            254             232
# 84  5/24/2020            752          29            179             174
#
#     active_pos  cases_in_hospital  total_confirmed  total_deaths  \
# 80        9645              10235            14229           680
# 81       10205              10786            15003           696
# 82       10826              11412            15786           707
# 83       11321              11885            16513           735
# 84       11899              12458            17265           764
#
#     total_recovered  total_pos_to_neg lockdown  lockdown_duration
# 80             3994              4584      Yes                  9
# ...

# %%
data.columns
# Out:
# Index(['date', 'new_confirmed', 'new_deaths', 'new_recovered',
#        'new_pos_to_neg', 'active_pos', 'cases_in_hospital', 'total_confirmed',
#        'total_deaths', 'total_recovered', 'total_pos_to_neg', 'lockdown',
#        'lockdown_duration'],
#       dtype='object')

# %%
data.describe()
# Out:
#        new_confirmed  new_deaths  new_recovered  new_pos_to_neg    active_pos  \
# count      85.000000   85.000000      85.000000       85.000000     85.000000
# mean      203.105882    8.988235      56.541176       63.117647   2832.305882
# std       211.650207    7.313546      70.724575       72.380018   3277.805171
# min         0.000000    0.000000       0.000000        0.000000      1.000000
# 25%        36.000000    2.000000       7.000000       10.000000    253.000000
# 50%       139.000000    9.000000      31.000000       37.000000   1476.000000
# 75%       338.000000   14.000000      70.000000       89.000000   4424.000000
# max       783.000000   29.000000     302.000000      309.000000  11899.000000
#
#        cases_in_hospital  total_confirmed  total_deaths  total_recovered  \
# count          85.000000        85.000000     85.000000        85.000000
# mean         3061.188235      4081.705882    234.305882      1020.517647
# ...

# %%
data.isnull().sum()
# Out:
# date                 0
# new_confirmed        0
# new_deaths           0
# new_recovered        0
# new_pos_to_neg       0
# active_pos           0
# cases_in_hospital    0
# total_confirmed      0
# total_deaths         0
# total_recovered      0
# total_pos_to_neg     0
# lockdown             0
# lockdown_duration    0
# dtype: int64

# %% [markdown]
# # Relating the variables with scatterplots

# %%
sns.relplot(x="active_pos" , y="total_recovered" , data=data)

# %%
sns.relplot(x="active_pos" , y="total_deaths" , data=data)

# %%
sns.relplot(x="active_pos" , y="total_confirmed" , data=data)

# %%
sns.relplot(x="active_pos" , y="total_pos_to_neg" , data=data)

# %%
sns.relplot(x="cases_in_hospital" , y="total_confirmed" , hue="total_recovered" , data=data)

# %%
sns.relplot(x="total_confirmed" , y="cases_in_hospital" , hue="total_recovered" , data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="active_pos" , y="total_recovered" , kind="line" , data=data)

# %%
sns.relplot(x="active_pos" , y="total_deaths" , kind="line" , data=data)

# %%
sns.relplot(x="active_pos" , y="total_confirmed" , kind="line" , data=data)

# %%
sns.relplot(x="active_pos" , y="total_pos_to_neg" , kind="line" , data=data)

# %%
sns.catplot(x="active_pos" , y="total_recovered" , data=data)

# %%
sns.catplot(x="active_pos" , y="total_deaths" , data=data)

# %%
sns.catplot(x="active_pos" , y="total_confirmed" , data=data)

# %%
sns.catplot(x="active_pos" , y="total_pos_to_neg" , data=data)
